# %% [markdown]
# <a href="https://colab.research.google.com/github/JayashanManodya/PlateX/blob/main/PlateX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
HOME = '/content/PLATES'
print(HOME)
# Out:
# /content/PLATES

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.202 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 39.5/235.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# /content/PLATES
# ...
# Ultralytics 8.3.202 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# image 1/1 /content/PLATES/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 220.4ms
# Speed: 15.3ms preprocess, 220.4ms inference, 241.6ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to /content/PLATES/runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

from google.colab import drive
drive.mount('/content/drive')
# Out:
# mkdir: cannot create directory ‘{HOME}/datasets’: No such file or directory
# [Errno 2] No such file or directory: '{HOME}/datasets'
# /content
# Mounted at /content/drive

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolo12s.pt data=/content/drive/MyDrive/License_Plate_Recognition_DataSet/data.yaml epochs=100 imgsz=640 plots=True
# Out:
# /content/PLATES
# ...
# Ultralytics 8.3.202 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
#end
